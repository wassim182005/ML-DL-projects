# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

df = pd.read_csv("insurance.csv")
profile = ProfileReport(df, title="My Data Report")

# Save as HTML file to view in browser
profile.to_file("insurance_repport.html")
print("Report saved as insurance_repport.html - open it in your browser")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 7/7 [00:00<00:00, 519.57it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Report saved as insurance_repport.html - open it in your browser

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df["sex"]=df["sex"].map({"male":0,"female":1})
df["smoker"]=df["smoker"].map({"yes":1,"no":0})
df["region"]=df["region"].map({"southeast":0,"southwest":1,"northeast":2,"northwest":3})
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       1  16884.92400
# 1   18    0  33.770         1       0       0   1725.55230
# 2   28    0  33.000         3       0       0   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.fillna(0)

target_name = "charges"

x = df.drop(columns=target_name)
y = df[target_name]
x.head()
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    1  27.900         0       1       1
# 1   18    0  33.770         1       0       0
# 2   28    0  33.000         3       0       0
# 3   33    0  22.705         0       0       3
# 4   32    0  28.880         0       0       3

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
model = LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)

print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R²  :", r2_score(y_test, y_pred))
# Out:
# MAE : 4181.347606911921
# MSE : 35604894.06638996
# RMSE: 5966.983665671456
# R²  : 0.8062382634707148
