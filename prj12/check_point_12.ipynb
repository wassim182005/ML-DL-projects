# %% [markdown]
# ## test imports ##

# %%
# %pip install torch

import torch
import torch.nn as nn
import torch.optim as optim






print("CUDA Available:", torch.cuda.is_available())
print("GPU Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")
# Out:
# Requirement already satisfied: torch in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# CUDA Available: True
# GPU Device: NVIDIA GeForce RTX 5070
# c:\Users\belw2\Desktop\ALL\ML && DL\venv\Lib\site-packages\torch\cuda\__init__.py:235: UserWarning:
# NVIDIA GeForce RTX 5070 with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_90.
# If you want to use the NVIDIA GeForce RTX 5070 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(
